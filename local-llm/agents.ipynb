# %%
from autogen import AssistantAgent, UserProxyAgent

config_list = [
  {
    "model": "llama3",
    "base_url": "http://localhost:11434/v1",
    "api_key": "ollama",
  }
]

# assistant = AssistantAgent("assistant", llm_config={"config_list": config_list})

# user_proxy = UserProxyAgent("user_proxy", code_execution_config={"work_dir": "coding", "use_docker": True})
# user_proxy.initiate_chat(assistant, message="hello")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from autogen import AssistantAgent, UserProxyAgent
#       3 config_list = [
#       4   {
#       5     "model": "llama3",
#    (...)
#       8   }
#       9 ]
#      11 assistant = AssistantAgent("assistant", llm_config={"config_list": config_list})
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/__init__.py:3
#       1 import logging
# ----> 3 from .agentchat import *
#       4 from .code_utils import DEFAULT_MODEL, FAST_MODEL
#       5 from .exception_utils import *
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/agentchat/__init__.py:2
#       1 from .agent import Agent
# ----> 2 from .assistant_agent import AssistantAgent
#       3 from .chat import ChatResult, initiate_chats
#       4 from .conversable_agent import ConversableAgent, register_function
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/agentchat/assistant_agent.py:5
#       1 from typing import Callable, Dict, Literal, Optional, Union
#       3 from autogen.runtime_logging import log_new_agent, logging_enabled
# ----> 5 from .conversable_agent import ConversableAgent
#       8 class AssistantAgent(ConversableAgent):
#       9     """(In preview) Assistant agent, designed to solve a task with LLM.
#      10
#      11     AssistantAgent is a subclass of ConversableAgent configured with a default system message.
#    (...)
#      16     This agent doesn't execute code by default, and expects the user to execute the code.
#      17     """
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:18
#      16 from .._pydantic import model_dump
#      17 from ..cache.cache import AbstractCache
# ---> 18 from ..code_utils import (
#      19     PYTHON_VARIANTS,
#      20     UNKNOWN,
#      21     check_can_use_docker_or_throw,
#      22     content_str,
#      23     decide_use_docker,
#      24     execute_code,
#      25     extract_code,
#      26     infer_lang,
#      27 )
#      28 from ..coding.base import CodeExecutor
#      29 from ..coding.factory import CodeExecutorFactory
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/code_utils.py:17
#      13 from typing import Any, Callable, Dict, List, Optional, Tuple, Union
#      15 import docker
# ---> 17 from autogen import oai
#      19 from .types import UserMessageImageContentPart, UserMessageTextContentPart
#      21 SENTINEL = object()
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/oai/__init__.py:3
#       1 from autogen.cache.cache import Cache
#       2 from autogen.oai.client import ModelClient, OpenAIWrapper
# ----> 3 from autogen.oai.completion import ChatCompletion, Completion
#       4 from autogen.oai.openai_utils import (
#       5     config_list_from_dotenv,
#       6     config_list_from_json,
#    (...)
#      11     get_config_list,
#      12 )
#      14 __all__ = [
#      15     "OpenAIWrapper",
#      16     "ModelClient",
#    (...)
#      26     "Cache",
#      27 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/oai/completion.py:10
#       7 from typing import Callable, Dict, List, Optional, Union
#       9 import numpy as np
# ---> 10 from flaml import BlendSearch, tune
#      11 from flaml.automl.logger import logger_formatter
#      12 from flaml.tune.space import is_constant
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/__init__.py:3
#       1 import logging
# ----> 3 from flaml.automl import AutoML, logger_formatter
#       4 from flaml.onlineml.autovw import AutoVW
#       5 from flaml.tune.searcher import CFO, FLOW2, BlendSearch, BlendSearchTuner, RandomSearch
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/__init__.py:1
# ----> 1 from flaml.automl.automl import AutoML, size
#       2 from flaml.automl.logger import logger_formatter
#       3 from flaml.automl.state import AutoMLState, SearchState
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/automl.py:19
#      17 from flaml import tune
#      18 from flaml.automl.logger import logger, logger_formatter
# ---> 19 from flaml.automl.ml import train_estimator
#      20 from flaml.automl.spark import DataFrame, Series, psDataFrame, psSeries
#      21 from flaml.automl.state import AutoMLState, SearchState
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/ml.py:11
#       7 from typing import Callable, Optional, Tuple, TypeVar, Union
#       9 import numpy as np
# ---> 11 from flaml.automl.data import group_counts
#      12 from flaml.automl.model import BaseEstimator, TransformersEstimator
#      13 from flaml.automl.spark import ERROR as SPARK_ERROR
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/data.py:11
#       7 from typing import TYPE_CHECKING, Union
#       9 import numpy as np
# ---> 11 from flaml.automl.spark import DataFrame, Series, pd, ps, psDataFrame, psSeries
#      12 from flaml.automl.training_log import training_log_reader
#      14 try:
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/spark/__init__.py:31
#      28     _spark_major_minor_version = VersionUtils.majorMinorVersion(pyspark.__version__)
#      30 try:
# ---> 31     import pandas as pd
#      32     from pandas import DataFrame, Series
#      33 except ImportError:
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/__init__.py:138
#     119 from pandas.core.computation.api import eval
#     121 from pandas.core.reshape.api import (
#     122     concat,
#     123     lreshape,
#    (...)
#     135     qcut,
#     136 )
# --> 138 from pandas import api, arrays, errors, io, plotting, tseries
#     139 from pandas import testing
#     140 from pandas.util._print_versions import show_versions
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/api/__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/api/typing/__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/json/__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/parsers/__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %%
from autogen import AssistantAgent, UserProxyAgent, ConversableAgent

config_list = [
  {
    "model": "llama3",
    "base_url": "http://localhost:11434/v1",
    "api_key": "ollama",
  }
]

agent = ConversableAgent("chatbot", llm_config={"config_list": config_list})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from autogen import AssistantAgent, UserProxyAgent, ConversableAgent
#       3 config_list = [
#       4   {
#       5     "model": "llama3",
#    (...)
#       8   }
#       9 ]
#      11 agent = ConversableAgent("chatbot", llm_config={"config_list": config_list})
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/__init__.py:3
#       1 import logging
# ----> 3 from .agentchat import *
#       4 from .code_utils import DEFAULT_MODEL, FAST_MODEL
#       5 from .exception_utils import *
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/agentchat/__init__.py:2
#       1 from .agent import Agent
# ----> 2 from .assistant_agent import AssistantAgent
#       3 from .chat import ChatResult, initiate_chats
#       4 from .conversable_agent import ConversableAgent, register_function
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/agentchat/assistant_agent.py:5
#       1 from typing import Callable, Dict, Literal, Optional, Union
#       3 from autogen.runtime_logging import log_new_agent, logging_enabled
# ----> 5 from .conversable_agent import ConversableAgent
#       8 class AssistantAgent(ConversableAgent):
#       9     """(In preview) Assistant agent, designed to solve a task with LLM.
#      10
#      11     AssistantAgent is a subclass of ConversableAgent configured with a default system message.
#    (...)
#      16     This agent doesn't execute code by default, and expects the user to execute the code.
#      17     """
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:18
#      16 from .._pydantic import model_dump
#      17 from ..cache.cache import AbstractCache
# ---> 18 from ..code_utils import (
#      19     PYTHON_VARIANTS,
#      20     UNKNOWN,
#      21     check_can_use_docker_or_throw,
#      22     content_str,
#      23     decide_use_docker,
#      24     execute_code,
#      25     extract_code,
#      26     infer_lang,
#      27 )
#      28 from ..coding.base import CodeExecutor
#      29 from ..coding.factory import CodeExecutorFactory
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/code_utils.py:17
#      13 from typing import Any, Callable, Dict, List, Optional, Tuple, Union
#      15 import docker
# ---> 17 from autogen import oai
#      19 from .types import UserMessageImageContentPart, UserMessageTextContentPart
#      21 SENTINEL = object()
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/oai/__init__.py:3
#       1 from autogen.cache.cache import Cache
#       2 from autogen.oai.client import ModelClient, OpenAIWrapper
# ----> 3 from autogen.oai.completion import ChatCompletion, Completion
#       4 from autogen.oai.openai_utils import (
#       5     config_list_from_dotenv,
#       6     config_list_from_json,
#    (...)
#      11     get_config_list,
#      12 )
#      14 __all__ = [
#      15     "OpenAIWrapper",
#      16     "ModelClient",
#    (...)
#      26     "Cache",
#      27 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/autogen/oai/completion.py:10
#       7 from typing import Callable, Dict, List, Optional, Union
#       9 import numpy as np
# ---> 10 from flaml import BlendSearch, tune
#      11 from flaml.automl.logger import logger_formatter
#      12 from flaml.tune.space import is_constant
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/__init__.py:3
#       1 import logging
# ----> 3 from flaml.automl import AutoML, logger_formatter
#       4 from flaml.onlineml.autovw import AutoVW
#       5 from flaml.tune.searcher import CFO, FLOW2, BlendSearch, BlendSearchTuner, RandomSearch
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/__init__.py:1
# ----> 1 from flaml.automl.automl import AutoML, size
#       2 from flaml.automl.logger import logger_formatter
#       3 from flaml.automl.state import AutoMLState, SearchState
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/automl.py:19
#      17 from flaml import tune
#      18 from flaml.automl.logger import logger, logger_formatter
# ---> 19 from flaml.automl.ml import train_estimator
#      20 from flaml.automl.spark import DataFrame, Series, psDataFrame, psSeries
#      21 from flaml.automl.state import AutoMLState, SearchState
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/ml.py:11
#       7 from typing import Callable, Optional, Tuple, TypeVar, Union
#       9 import numpy as np
# ---> 11 from flaml.automl.data import group_counts
#      12 from flaml.automl.model import BaseEstimator, TransformersEstimator
#      13 from flaml.automl.spark import ERROR as SPARK_ERROR
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/data.py:11
#       7 from typing import TYPE_CHECKING, Union
#       9 import numpy as np
# ---> 11 from flaml.automl.spark import DataFrame, Series, pd, ps, psDataFrame, psSeries
#      12 from flaml.automl.training_log import training_log_reader
#      14 try:
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/flaml/automl/spark/__init__.py:31
#      28     _spark_major_minor_version = VersionUtils.majorMinorVersion(pyspark.__version__)
#      30 try:
# ---> 31     import pandas as pd
#      32     from pandas import DataFrame, Series
#      33 except ImportError:
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/__init__.py:138
#     119 from pandas.core.computation.api import eval
#     121 from pandas.core.reshape.api import (
#     122     concat,
#     123     lreshape,
#    (...)
#     135     qcut,
#     136 )
# --> 138 from pandas import api, arrays, errors, io, plotting, tseries
#     139 from pandas import testing
#     140 from pandas.util._print_versions import show_versions
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/api/__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/api/typing/__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/json/__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/json/_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/parsers/__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File ~/Developer/cha9ro/llm-snipets/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)
